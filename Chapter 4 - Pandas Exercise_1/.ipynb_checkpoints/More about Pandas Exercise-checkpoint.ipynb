# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Time for some practice!
#
# Time to put to practice what we have just covered. We need to start off by reading three csvs; naijaprop.csv, proppro.csv and trovit.csv. Save each of these dataframes as naijaprop, proppro and trovit respectively.
#
# Print out the first 5 rows of each dataframe and descriptive information regarding the columns in each dataframe

# %%
#answer here

naijaprop = pd.read_csv('naijaprop.csv')
proppro = pd.read_csv('proppro.csv')
trovit = pd.read_csv('trovit.csv')

# %%
naijaprop.head()
# Out:
#        price      unit                                           location  \
# 0  1,000,000  per Year  15 - 17 Bolaji Balogun Street, Ayonusi Estate,...
# 1    600,000  per Year  15 - 17 Bolaji Balogun Street, Ayonusi Estate,...
# 2    250,000  per Year                       badore,owode and addo roads,
# 3  1,000,000  per Year                                           ilupeju,
# 4    600,000  per Year                                       badore road,
#
#    bedrooms  baths  state
# 0       5.0    6.0  Lagos
# 1       3.0    3.0  Lagos
# 2       1.0    1.0  Lagos
# 3       3.0    2.0  Lagos
# 4       NaN    NaN  Lagos

# %%
proppro.head()
# Out:
#         price      unit location bedrooms   baths  state
# 0   2,500,000  per Year             2 bed  2 bath    NaN
# 1   1,400,000  per Year             2 bed  2 bath    NaN
# 2   2,200,000  per Year             3 bed  2 bath    NaN
# 3   6,000,000  per Year             3 bed  3 bath    NaN
# 4  62,000,000  per Year             3 bed  3 bath    NaN

# %%
trovit.head()
# Out:
#       price      unit                                location bedrooms baths  \
# 0  ₦450,000  per Year                Ogun, Odeda, Ogun State         2     2
# 1  ₦150,000  per Year   Abeokuta, Abeokuta South, Ogun State         1     1
# 2  ₦700,000  per Year                Ogun, Odeda, Ogun State         3     3
# 3  ₦250,000  per Year                        Ifo, Ogun State         2     2
# 4  ₦200,000  per Year       Ofada, Obafemi Owode, Ogun State       NaN   NaN
#
#    state
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %% [markdown]
# ## Question 1
#
# Create a new column for each dataframe, name this column <strong><i>source</i></strong> and label the values in the column based on the source of the listing. For example, all the listings in castles should be labeled as castles in the column we named <strong><i>source</i></strong>

# %%
#answer here

naijaprop['source'] = 'naijaprop'
proppro['source'] = 'proppop'
trovit['source'] = 'trovit'

# %% [markdown]
# ## Question 2
#
# Now, concatenate all the dataframes you have just read into one dataframe. This would be the equivalent of an outer merge, you should have a dataframe with <strong>18357 rows</strong> and <strong>6 columns</strong>, assign this to a variable named merged_df.

# %%
#answer here

merged_df = naijaprop.append([proppro, trovit])
merged_df.shape
merged_df.columns
# Out:
# Index(['price', 'unit', 'location', 'bedrooms', 'baths', 'state', 'source'], dtype='object')

# %% [markdown]
# ## Question 3
#
# We are going to do a bit of data cleaning, we need to remove the Naira sign from all the prices in our price column. This is a good add that for every issue you may encounter when writing code there is a good probability that someone has experienced something similar. If you do not know how to remove non numerical characters from a column, try Google this query with the phrase <strong><i>site:stackoverflow.com</i></strong> added to the end of your query and read a few answers with people trying different solutions and customize one of those for this question.

# %%
merged_df.price.isna().sum()
# Out:
# 288

# %%
#answer here

merged_df['price'] = merged_df.price.apply(lambda x: ''.join([i for i in x if i.isdigit()]))
merged_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-148-79f927e20c81> in <module>
#       1 #answer here
#       2
# ----> 3 merged_df['price'] = merged_df.price.apply(lambda x: ''.join([i for i in x if i.isdigit()]))
#       4 merged_df.head()
#
# C:\Anaconda\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-148-79f927e20c81> in <lambda>(x)
#       1 #answer here
#       2
# ----> 3 merged_df['price'] = merged_df.price.apply(lambda x: ''.join([i for i in x if i.isdigit()]))
#       4 merged_df.head()
#
# TypeError: 'float' object is not iterable

# %%
merged_df.describe()
# Out:
#           price      unit location bedrooms  baths  state   source
# count     18069     18357    18357    17926  17925     20    18357
# unique      443         1     3656       48     48      3        3
# top     300,000  per Year             3 bed   bath  Lagos  proppop
# freq        788     18357     1588     3499   4847     16    11640

# %% [markdown]
# ## Question 4
#
# Find the missing and NaN values in the bedrooms and baths columns, how do you want to treat these missing values, there is no right or wrong answer. Find the most appropriate solution and explain your logic, ie why did you choose that particular method, what impact might it have on the accuracy and integrity of our data?

# %%
#answer here

merged_df[['bedrooms', 'baths']] = merged_df[['bedrooms', 'baths']].fillna(method='pad')
merged_df.head(10)
# Out:
#         price      unit                                           location  \
# 0   1,000,000  per Year  15 - 17 Bolaji Balogun Street, Ayonusi Estate,...
# 1     600,000  per Year  15 - 17 Bolaji Balogun Street, Ayonusi Estate,...
# 2     250,000  per Year                       badore,owode and addo roads,
# 3   1,000,000  per Year                                           ilupeju,
# 4     600,000  per Year                                       badore road,
# 5     400,000  per Year                                       badore road,
# 6   3,700,000  per Year                           Choba Uniport Road, Ph.,
# 7         100  per Year                               Ozuoba NTA road Ph.,
# 8  12,500,000  per Year                                             Ikoyi,
# 9   1,500,000  per Year                                           alapere,
#
#   bedrooms baths   state     source
# 0        5     6   Lagos  naijaprop
# 1        3     3   Lagos  naijaprop
# 2        1     1   Lagos  naijaprop
# 3        3     2   Lagos  naijaprop
# 4        3     2   Lagos  naijaprop
# 5        1     1   Lagos  naijaprop
# 6        2     2  Rivers  naijaprop
# 7        2     2  Rivers  naijaprop
# 8        3     3   Lagos  naijaprop
# 9        3     2   Lagos  naijaprop

# %% [markdown]
# ## Question 5
#
# You will notice that some listings do not have a state, instead the state is included in the location. Select all rows in the dataset where the value in the location columns contains the word <strong><i>State</i></strong> and where the state column contains an NaN value

# %%
#answer here

nan_df = merged_df[merged_df['state'].isna() & merged_df['location'].apply(lambda x: 'state' in x)]
nan_df
# Out:
#            price      unit                                           location  \
# 872      850,000  per Year   nspm cooperative housing estate by second gat...
# 1068   3,500,000  per Year           udi osborne foreshore estate ikoyi lagos
# 1641   2,000,000  per Year                 road 43, carlton gate estate lagos
# 1649     450,000  per Year   aina ajayi estate ekoro road abule egba abule...
# 1655     700,000  per Year   s-forte estate, ajah, opposite eco bank ado a...
# 1657   1,200,000  per Year   s-forte estate, ajah, opposite eco bank ado a...
# 1672   1,000,000  per Year    baba omojola estate millenuim ups gbagada lagos
# 1675     400,000  per Year                 medina estate medina gbagada lagos
# 1677   2,500,000  per Year               maryland estate mende maryland lagos
# 1762    1 bed  1 bath   NaN  proppop
# 1763    3 bed  3 bath   NaN  proppop
# 1764    4 bed  4 bath   NaN  proppop
# 1767    3 bed  3 bath   NaN  proppop
# 1769    2 bed  2 bath   NaN  proppop
# 1770    3 bed  3 bath   NaN  proppop
# 1772    2 bed  2 bath   NaN  proppop
# 1773    0 bed  0 bath   NaN  proppop
# ...       ...     ...   ...      ...
# 4026        4       4   NaN   trovit
# 4040        3       3   NaN   trovit
# 4098        4       4   NaN   trovit
# 4128        4       4   NaN   trovit
# 4143        4       4   NaN   trovit
# 4145        5       5   NaN   trovit
# 4188        3       3   NaN   trovit
# 4199        4       4   NaN   trovit
# 4232        4       4   NaN   trovit
# 4236        3       3   NaN   trovit
# 4290        4       4   NaN   trovit
# 4294        4       4   NaN   trovit
# 4299        4       4   NaN   trovit
# 4354        3       3   NaN   trovit
# 4586        3       3   NaN   trovit
# 4798        5       5   NaN   trovit
# 4926        3       3   NaN   trovit
# 4932        4       4   NaN   trovit
# 4979        4       4   NaN   trovit
# 4989        3       3   NaN   trovit
# 4999        3       3   NaN   trovit
# 5000        3       3   NaN   trovit
# 5029        3       3   NaN   trovit
# 5037        3       3   NaN   trovit
# 5076        3       3   NaN   trovit
# 5086        3       3   NaN   trovit
# 5093        3       3   NaN   trovit
# 5130        2       2   NaN   trovit
# 5133        2       2   NaN   trovit
# 5142        3       3   NaN   trovit
#
# [1071 rows x 7 columns]

# %% [markdown]
# ## Question 6
#
# Ok, we are going to think of a way to clean up our data. Where we have an NaN value in the state column we are going to extract the state from the location column and append the value to the state column.
# We are going to try and find a simple solution for this.
#
# Let's start off by listing all unique states values in our merged_df dataframe

# %%
#answer here

unique_states = merged_df.state.unique()[:-1]
unique_states
# Out:
# array(['Lagos', 'Rivers', 'Ogun'], dtype=object)

# %% [markdown]
# ## Question 7
#
# We are going to make the assumption that the list we just created is a list of all the states detailed in our list. Remember only about a third of listings have no state, we can assume that the remainder of the 2/3rd would probably have listings from all the states covered in our merged_df dataframe. Let's check how accurate our assumption is.
#
# You need to find all rows under the column <strong><i>'location'</i></strong> containing the strings in the list we created in Question 6 and replace the NaN value in state with the name of the state that the row contains
#
# For example if a row has the value <strong>Lagos State</strong> rename the state column with the value <strong>Lagos</strong>
#
# Here is a tip, convert all the strings in location column to lower case and then search for strings that contain the values you found in Question 6 (convert these to lower case too)

# %%
#answer here

nan_df['state'] = nan_df['location'].apply(lambda x: ', '.join([i for i in unique_states if i.lower() in x.lower()]))
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
nan_df.head()
# Out:
#           price      unit                                           location  \
# 872     850,000  per Year   nspm cooperative housing estate by second gat...
# 1068  3,500,000  per Year           udi osborne foreshore estate ikoyi lagos
# 1641  2,000,000  per Year                 road 43, carlton gate estate lagos
# 1649    450,000  per Year   aina ajayi estate ekoro road abule egba abule...
# 1655    700,000  per Year   s-forte estate, ajah, opposite eco bank ado a...
#
#      bedrooms   baths  state   source
# 872     3 bed  3 bath  Lagos  proppop
# 1068    3 bed  3 bath  Lagos  proppop
# 1641    3 bed  3 bath  Lagos  proppop
# 1649    3 bed  2 bath  Lagos  proppop
# 1655    1 bed  1 bath  Lagos  proppop

# %%
', '.join([i for i in unique_states if i.lower() in 'Parkview Estate, Eti Osa, Lagos State ogun'.lower()])
# Out:
# 'Lagos, Ogun'

# %% [markdown]
# ## Question 8
#
# Let' check how many NaN values we have under the state column now

# %%
#answer here

nan_df.state.unique()
# Out:
# array(['Lagos', 'Lagos, Ogun', 'Rivers', '', 'Ogun'], dtype=object)

# %% [markdown]
# ## Question 9
#
# Ok, so we still have NaN values, print out all the unique values in the <strong><i>location</i></strong> column for rows that still have an NaN values under the <strong><i>state</i></strong> column. You will notice that there actually aren't too many unique states. There are however, a lot of unique locations. Let's try and rename the states column based on the unique states we identify. Keep checking whether or not you have filled all NaN values under state.
#
# <i>Please document your solution, explain what you did and why</i>

# %%
#answer here

# %% [markdown]
# ## Question 10
#
# Which state has the most expensive listing?
#
# <i>Show the code you used to find this listing</i>

# %%
#answer here
most_expensive_state = merged_df['state'][merged_df.price == merged_df.price.max()]
most_expensive_state
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     126                 else:
# --> 127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             except Exception:
#
# C:\Anaconda\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna, mask)
#     741         else:
# --> 742             result = getattr(values, meth)(axis)
#     743
#
# C:\Anaconda\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims, initial)
#      27           initial=_NoValue):
# ---> 28     return umr_maximum(a, axis, None, out, keepdims, initial)
#      29
#
# TypeError: '>=' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-180-6dc18ec1c4ee> in <module>
#       1 #answer here
# ----> 2 most_expensive_state = merged_df['state'][merged_df.price == merged_df.price.max()]
#       3 most_expensive_state
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   10954                                       skipna=skipna)
#   10955         return self._reduce(f, name, axis=axis, skipna=skipna,
# > 10956                             numeric_only=numeric_only)
#   10957
#   10958     return set_function_name(stat_func, name, cls)
#
# C:\Anaconda\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3628                                           'numeric_only.'.format(name))
#    3629             with np.errstate(all='ignore'):
# -> 3630                 return op(delegate, skipna=skipna, **kwds)
#    3631
#    3632         # TODO(EA) dispatch to Index
#
# C:\Anaconda\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     128             except Exception:
#     129                 try:
# --> 130                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     131                 except ValueError as e:
#     132                     # we want to transform an object array
#
# C:\Anaconda\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna, mask)
#     740                 result = np.nan
#     741         else:
# --> 742             result = getattr(values, meth)(axis)
#     743
#     744         result = _wrap_results(result, dtype, fill_value)
#
# C:\Anaconda\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims, initial)
#      26 def _amax(a, axis=None, out=None, keepdims=False,
#      27           initial=_NoValue):
# ---> 28     return umr_maximum(a, axis, None, out, keepdims, initial)
#      29
#      30 def _amin(a, axis=None, out=None, keepdims=False,
#
# TypeError: '>=' not supported between instances of 'str' and 'float'

# %%
naijaprop.price.min()
# Out:
# '1,000,000'

# %% [markdown]
# ## Question 11
#
# Which state has the least expensive listing?
#
# <i>Show the code you used to find this listing</i>

# %%
#answer here#answer here
least_expensive_state = merged_df['state'][merged_df.price == merged_df.price.max()]
least_expensive_state

# %% [markdown]
# ## Question 12
#
# Save <strong>merged_df</strong> as a csv file in your computer, use whatever name you will feel comfortable with

# %%
#answer here
merged_df.to_csv('merged_df.csv')

# %%
merged_df
# Out:
#         price      unit                                           location  \
# 0     1000000  per Year  15 - 17 bolaji balogun street, ayonusi estate,...
# 1      600000  per Year  15 - 17 bolaji balogun street, ayonusi estate,...
# 2      250000  per Year                       badore,owode and addo roads,
# 3     1000000  per Year                                           ilupeju,
# 4      600000  per Year                                       badore road,
# ...       ...       ...                                                ...
# 6692    80000  per Year                              ikorodu, lagos state
# 6693  1500000  per Year                        ajah, eti osa, lagos state
# 6694  1500000  per Year                   lekki, ibeju lekki, lagos state
# 6695  1200000  per Year                   lekki, ibeju lekki, lagos state
# 6696    80000  per Year                              ikorodu, lagos state
#
#      bedrooms baths  state
# 0           5     6   Ogun
# 1           3     3  Lagos
# 2           1     1  Lagos
# 3           3     2  Lagos
# 4         NaN   NaN  Lagos
# ...       ...   ...    ...
# 6692        1     1  Lagos
# 6693        4     4  Lagos
# 6694        3     3  Lagos
# 6695        2     2  Lagos
# 6696        1     1  Lagos
#
# [18357 rows x 6 columns]
