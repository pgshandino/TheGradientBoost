# %%
# %matplotlib inline
import ipywidgets as widgets
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
plt.rcParams['savefig.dpi'] = 144

# %% [markdown]
# ## Context
#
# Analytics has permeated all industries as a result of an exponential increase in data collection. More service providers have access to more information to better understand what customers want. The same applies to the credit card industry. Within the credit card payment processing field, significant amounts of data is available
# to understand a multitude of consumer behaviour, including their spending patterns.
#
# This data can also be used to understand transactions and activities from existing customers to identify trends that are emerging in different regions. This information can also be used to better understand our customers and identify channels to better engage with prospective customers.
#
# Additional to this, data acquired from credit processing is becoming an increasingly important tool as a fight against fraud. Combined with Machine Learning, this data can be analyzed quickly to uncover suspicious purchase activit

# %% [markdown]
# ## Business Problem
#
# In order to make better decisions, Ms. Juliet Sithole the CEO of KECredits would like to start taking data analysis more seriously in guiding her decisions. She comes to you with a list of questions with the objective of developing a better understanding of customer spending habits and repayment behaviour
#
#
# __1.__ We would like to understand spending patterns for each customer. Please help us understand what each customer spent during each month in 2004, 2005 and 2006<br>
# __2.__ What is the average monthly spend by each customer for each month?<br>
# __3.__ What are the top 3 months in terms of average spend by month?<br>
# __4.__ Which 10 customers spend the most money in festive season months (November and December) and winter months (May, June and July). We need two dataframes<br>
# __5.__ Which month do we record more customer spend in, does this differ by year?<br>
# __6.__ Which month do we record more customers spending money in terms of number of transactions?<br>
# __7.__ What are most customers spending money on, does this change by month?<br>
# __8.__ What products are users under the age of 21 spending more money on?<br>
# __9.__ What products are users between the ages of 25 and 40, spending more money on, does this differ depending on the city they are from?<br>

# %% [markdown]
# ## Data
#
# Get the data and clean for analysis

# %%
customer_file = "customer_information.csv"
spending_file = "spend.csv"

customer_df = pd.read_csv(customer_file)
spending_df = pd.read_csv(spending_file)

# %%
customer_df.head()
# Out:
#    Unnamed: 0  No Customer  Age     City   Product     Limit Company  \
# 0           0   1       A1   76  Nairobi      Gold  500000.0      C1
# 1           1   2       A2   71  Mombasa    Silver  100000.0      C2
# 2           2   3       A3   34   Kisumu  Platimum   10000.0      C3
# 3           3   4       A4   47   Nakuru  Platimum   10001.0      C4
# 4           4   5       A5   56  Nairobi  Platimum   10002.0      C5
#
#          Segment
# 0  Self Employed
# 1   Salaried_MNC
# 2   Salaried_Pvt
# 3           Govt
# 4  Normal Salary

# %%
customer_df = customer_df.drop(['Unnamed: 0', 'No',], axis=1)
customer_df.head()
# Out:
#   Customer  Age     City   Product     Limit Company        Segment
# 0       A1   76  Nairobi      Gold  500000.0      C1  Self Employed
# 1       A2   71  Mombasa    Silver  100000.0      C2   Salaried_MNC
# 2       A3   34   Kisumu  Platimum   10000.0      C3   Salaried_Pvt
# 3       A4   47   Nakuru  Platimum   10001.0      C4           Govt
# 4       A5   56  Nairobi  Platimum   10002.0      C5  Normal Salary

# %%
spending_df.head()
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1  12-Jan-04  JEWELLERY  485470.80
# 1       2       A1   3-Jan-04      PETRO  410556.13
# 2       3       A1  15-Jan-04    CLOTHES   23740.46
# 3       4       A1  25-Jan-04       FOOD  484342.47
# 4       5       A1  17-Jan-05     CAMERA  369694.07

# %%
spending_df = spending_df.drop('Sl No:', axis=1)

# %%
spending_df = spending_df.sort_values(by='Month', ascending=True)

# %%
spending_df.head()
# Out:
#      Customer     Month        Type     Amount
# 1398      A40  1-Apr-06        FOOD  236231.22
# 1180      A54  1-Apr-06      RENTAL  410461.33
# 199       A14  1-Apr-06  BUS TICKET  341157.43
# 90        A89  1-Apr-06   JEWELLERY   24972.02
# 308       A21  1-Apr-06      CAMERA  265164.32

# %%
df = pd.merge(customer_df, spending_df, on='Customer')
df.head(20)
# Out:
#    Customer  Age     City Product     Limit Company        Segment      Month  \
# 0        A1   76  Nairobi    Gold  500000.0      C1  Self Employed   1-Feb-05
# 1        A1   76  Nairobi    Gold  500000.0      C1  Self Employed  12-Jan-04
# 2        A1   76  Nairobi    Gold  500000.0      C1  Self Employed  12-Jan-04
# 3        A1   76  Nairobi    Gold  500000.0      C1  Self Employed  15-Jan-04
# 4        A1   76  Nairobi    Gold  500000.0      C1  Self Employed  17-Jan-05
# 5        A1   76  Nairobi    Gold  500000.0      C1  Self Employed  19-Apr-06
# 6        A1   76  Nairobi    Gold  500000.0      C1  Self Employed   2-Apr-06
# 7        A1   76  Nairobi    Gold  500000.0      C1  Self Employed  22-Nov-05
# 8        A1   76  Nairobi    Gold  500000.0      C1  Self Employed  23-Feb-05
# 9        A1   76  Nairobi    Gold  500000.0      C1  Self Employed  23-Feb-05
# 10       A1   76  Nairobi    Gold  500000.0      C1  Self Employed  25-Jan-04
# 11       A1   76  Nairobi    Gold  500000.0      C1  Self Employed  25-Jan-04
# 12       A1   76  Nairobi    Gold  500000.0      C1  Self Employed   3-Aug-05
# 13       A1   76  Nairobi    Gold  500000.0      C1  Self Employed   3-Feb-05
# 14       A1   76  Nairobi    Gold  500000.0      C1  Self Employed   3-Jan-04
# 15       A1   76  Nairobi    Gold  500000.0      C1  Self Employed   3-Oct-06
# 16       A1   76  Nairobi    Gold  500000.0      C1  Self Employed   5-Feb-04
# 17       A1   76  Nairobi    Gold  500000.0      C1  Self Employed   5-May-04
# 18       A2   71  Mombasa  Silver  100000.0      C2   Salaried_MNC  12-Jan-04
# 19       A2   71  Mombasa  Silver  100000.0      C2   Salaried_MNC  23-Nov-04
#
#             Type     Amount
# 0            CAR   23370.20
# 1      JEWELLERY  485470.80
# 2   TRAIN TICKET  440563.22
# 3        CLOTHES   23740.46
# 4         CAMERA  369694.07
# 5     AIR TICKET  346925.68
# 6   TRAIN TICKET  176372.82
# 7          PETRO  183839.61
# 8        SANDALS  168285.60
# 9        CLOTHES  476702.09
# 10  TRAIN TICKET  394970.96
# 11          FOOD  484342.47
# 12  MOVIE TICKET  344372.10
# 13          FOOD  155611.91
# 14         PETRO  410556.13
# 15        RENTAL  244534.68
# 16    BUS TICKET   52208.65
# 17    BUS TICKET  361141.31
# 18        RENTAL  366519.94
# 19         PETRO  384078.73

# %%
df.shape
# Out:
# (1500, 10)

# %%
df['day'] = df['Month'].astype(np.datetime64).dt.weekday_name
df['month'] = df['Month'].astype(np.datetime64).dt.month_name()
df['year'] = df['Month'].astype(np.datetime64).dt.year

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df['month'] = pd.Categorical(df['month'], categories=months, ordered=True)

# %%
df.head()
# Out:
#   Customer  Age     City Product     Limit Company        Segment      Month  \
# 0       A1   76  Nairobi    Gold  500000.0      C1  Self Employed   1-Feb-05
# 1       A1   76  Nairobi    Gold  500000.0      C1  Self Employed  12-Jan-04
# 2       A1   76  Nairobi    Gold  500000.0      C1  Self Employed  12-Jan-04
# 3       A1   76  Nairobi    Gold  500000.0      C1  Self Employed  15-Jan-04
# 4       A1   76  Nairobi    Gold  500000.0      C1  Self Employed  17-Jan-05
#
#            Type     Amount       day     month  year
# 0           CAR   23370.20   Tuesday  February  2005
# 1     JEWELLERY  485470.80    Monday   January  2004
# 2  TRAIN TICKET  440563.22    Monday   January  2004
# 3       CLOTHES   23740.46  Thursday   January  2004
# 4        CAMERA  369694.07    Monday   January  2005

# %% [markdown]
# __1.__ We would like to understand spending patterns for each customer. Please help us understand what each customer spent during each month in 2004, 2005 and 2006

# %%
df_2004_2006 = df.loc[df.year.between(2004, 2006)]
df_2004_2006.head()
# Out:
#   Customer  Age     City Product     Limit Company        Segment      Month  \
# 0       A1   76  Nairobi    Gold  500000.0      C1  Self Employed   1-Feb-05
# 1       A1   76  Nairobi    Gold  500000.0      C1  Self Employed  12-Jan-04
# 2       A1   76  Nairobi    Gold  500000.0      C1  Self Employed  12-Jan-04
# 3       A1   76  Nairobi    Gold  500000.0      C1  Self Employed  15-Jan-04
# 4       A1   76  Nairobi    Gold  500000.0      C1  Self Employed  17-Jan-05
#
#            Type     Amount       day     month  year
# 0           CAR   23370.20   Tuesday  February  2005
# 1     JEWELLERY  485470.80    Monday   January  2004
# 2  TRAIN TICKET  440563.22    Monday   January  2004
# 3       CLOTHES   23740.46  Thursday   January  2004
# 4        CAMERA  369694.07    Monday   January  2005

# %%
df_2004_2006.sort_values(by='Month', ascending=True, inplace=True)
df_2004_2006 = df_2004_2006.groupby(['Customer', 'month'])['Amount'].sum().reset_index()
df_2004_2006.sort_values(by=['Customer', 'month'], ascending=True, inplace=True)
df_2004_2006.head(20)
# Out:
#    Customer     month      Amount
# 0        A1   January  2609338.11
# 1        A1  February   876178.45
# 2        A1     April   523298.50
# 3        A1       May   361141.31
# 4        A1    August   344372.10
# 5        A1   October   244534.68
# 6        A1  November   183839.61
# 7       A10   January   483432.98
# 8       A10  February   778230.67
# 9       A10     March   403893.80
# 10      A10     April   270721.68
# 11      A10       May   756829.57
# 12      A10      July   239798.03
# 13      A10    August   454827.23
# 14      A10  November   459690.69
# 15     A100   January   224786.88
# 16      A11   January   390896.71
# 17      A11  February   951369.35
# 18      A11     March   531306.46
# 19      A11     April   483603.21

# %%
@widgets.interact(customers=df_2004_2006.Customer.unique())

def plot(customers='A1'):
    
    df_2004_2006.loc[df_2004_2006.Customer == customers].plot(kind='bar', x='month', )
#     fig, ax = plt.subplots(1, 1, figsize=(20, 5))
#     ax.plot(df_2004_2006.loc[df_2004_2006['Customer'] == customers], x=['year', 'month'], y='Amount')
# Out:
# interactive(children=(Dropdown(description='customers', options=('A1', 'A10', 'A100', 'A11', 'A12', 'A13', 'A1…

# %%
# fig, ax = plt.subplots(figsize=(20,10))
# sns.set_context('notebook')
# ax = sns.barplot(data=df_2004_2006, x='Customer', y='Amount', hue='month')
# plt.show()

# %% [markdown]
# __2.__ What is the average monthly spend by each customer for each month?

# %%
avg_spennd_monthly = df.groupby(['Customer', 'month'])['Amount'].mean().reset_index()
avg_spennd_monthly.head()
# Out:
#   Customer     month         Amount
# 0       A1   January  372762.587143
# 1       A1  February  175235.690000
# 2       A1     April  261649.250000
# 3       A1       May  361141.310000
# 4       A1    August  344372.100000

# %%
@widgets.interact(customers=['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10'])

def avg_spend(customers='A1'):
    
    avg_spennd_monthly.loc[avg_spennd_monthly.Customer == customers].plot(kind='bar', x='month', )
# Out:
# interactive(children=(Dropdown(description='customers', options=('A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8…

# %% [markdown]
# __3.__ What are the top 3 months in terms of average spend by month?

# %%
avg_per_mnth = df.groupby('month')['Amount'].mean().reset_index()
# avg_per_mnth.sort_values(by='Amount', ascending=False, inplace=True)
avg_per_mnth
# Out:
#         month         Amount
# 0     January  256221.133553
# 1    February  233037.216471
# 2       March  246255.783723
# 3       April  236671.847533
# 4         May  241277.023476
# 5        June  241329.181250
# 6        July  268042.287143
# 7      August  236056.328571
# 8   September  219369.892143
# 9     October  215352.487857
# 10   November  249099.824405
# 11   December  208987.020357

# %%
sns.set()
sns.set_style('whitegrid')
sns.set_context('notebook')
fig, ax = plt.subplots(figsize=(12,6))

sns.barplot(data=avg_per_mnth, x='month', y='Amount')
ax.set_xticks(range(len(avg_per_mnth)))
ax.set_xticklabels(avg_per_mnth.month.unique())
plt.xlabel("Month")
plt.ylabel('Amount')
plt.title('Average Spending by Month')

plt.savefig('Q3_average_spending_by month(barplot).png')
plt.show()

# %%
avg_per_mnth.sort_values(by='Amount', ascending=False, inplace=True)

# %%
sns.set()
sns.set_style('whitegrid')
sns.set_context('notebook')
fig, ax = plt.subplots(figsize=(12,6))

plt.plot(range(1, len(avg_per_mnth)+1), avg_per_mnth.Amount)
ax.set_xticks(range(1, len(avg_per_mnth)+1))
ax.set_xticklabels(avg_per_mnth.month.unique())
plt.xlabel("Month")
plt.ylabel('Amount')
plt.title('Average Spending by Month in Descending Order')

plt.savefig('Q3_avg_spending_by_mnth_in_decending_order.png')
plt.show()

# %% [markdown]
# __4.__ Which 10 customers spend the most money in festive season months (November and December) and winter months (May, June and July). We need two dataframes

# %%
festive_mnths = df.loc[df.month.isin(['November', 'December'])]
festive_mnths.head()
# Out:
#    Customer  Age     City   Product     Limit Company        Segment  \
# 7        A1   76  Nairobi      Gold  500000.0      C1  Self Employed
# 19       A2   71  Mombasa    Silver  100000.0      C2   Salaried_MNC
# 24       A2   71  Mombasa    Silver  100000.0      C2   Salaried_MNC
# 34       A3   34   Kisumu  Platimum   10000.0      C3   Salaried_Pvt
# 47       A4   47   Nakuru  Platimum   10001.0      C4           Govt
#
#         Month          Type     Amount       day     month  year
# 7   22-Nov-05         PETRO  183839.61   Tuesday  November  2005
# 19  23-Nov-04         PETRO  384078.73   Tuesday  November  2004
# 24   3-Nov-06  MOVIE TICKET   75728.35    Friday  November  2006
# 34   3-Dec-06     JEWELLERY  491710.50    Sunday  December  2006
# 47   3-Nov-05       CLOTHES   23040.07  Thursday  November  2005

# %%
top_spending_festive = festive_mnths.groupby('Customer')['Amount'].sum().reset_index()
top_spending_festive.sort_values(by='Amount', ascending=False, inplace=True)
top_spending_festive.head(10)
# Out:
#    Customer      Amount
# 14      A22  1377630.85
# 19      A27  1158049.59
# 54      A62  1139662.93
# 34      A41  1138169.32
# 28      A36  1122009.63
# 10      A19   892197.56
# 13      A21   854385.42
# 12      A20   823395.26
# 53      A61   775188.92
# 27      A35   766607.33

# %%
winter_mnths = df.loc[df.month.isin(['May', 'June', 'July'])]
winter_mnths.head()
# Out:
#    Customer  Age     City   Product     Limit Company        Segment  \
# 17       A1   76  Nairobi      Gold  500000.0      C1  Self Employed
# 28       A2   71  Mombasa    Silver  100000.0      C2   Salaried_MNC
# 31       A3   34   Kisumu  Platimum   10000.0      C3   Salaried_Pvt
# 39       A3   34   Kisumu  Platimum   10000.0      C3   Salaried_Pvt
# 46       A4   47   Nakuru  Platimum   10001.0      C4           Govt
#
#         Month          Type     Amount        day month  year
# 17   5-May-04    BUS TICKET  361141.31  Wednesday   May  2004
# 28   6-May-06  TRAIN TICKET  369689.78   Saturday   May  2006
# 31  24-May-05         PETRO  183707.24    Tuesday   May  2005
# 39   7-May-05        RENTAL  285184.71   Saturday   May  2005
# 46  25-May-05         PETRO   31107.95  Wednesday   May  2005

# %%
top_winter_spenders = winter_mnths.groupby('Customer')['Amount'].sum().reset_index()
top_winter_spenders.sort_values(by='Amount', ascending=False, inplace=True)
top_winter_spenders.head(10)
# Out:
#    Customer      Amount
# 56      A60  2868123.22
# 31      A38  2797132.68
# 39      A45  2483197.66
# 4       A13  2387277.32
# 42      A48  2300607.55
# 5       A14  2118808.25
# 57      A61  2026678.84
# 3       A12  1982730.34
# 23      A30  1910820.33
# 32      A39  1903512.61

# %% [markdown]
# __5.__ Which month do we record more customer spend in, does this differ by year?

# %%
top_months = df.groupby(['year', 'month'])['Amount'].sum().reset_index()
top_months.sort_values(by='Amount',ascending=False, inplace=True)
top_months
# Out:
#     year      month       Amount
# 0   2004    January  77275605.08
# 20  2006      March  53635040.37
# 8   2005   February  38606783.01
# 10  2005        May  34397512.16
# 21  2006      April  21852082.95
# 22  2006        May  13225113.46
# 16  2005   November  12018019.56
# 11  2005       June  11032900.74
# 19  2006   February  10662046.95
# 7   2005    January   8196758.44
# 24  2006       July   8050142.77
# 9   2005      April   7061077.14
# 3   2004      April   6587617.04
# 13  2005     August   6544569.76
# 1   2004   February   6194027.56
# 28  2006   November   5119556.12
# 5   2004  September   4352927.37
# 18  2006    January   3948812.09
# 6   2004   November   3786809.57
# 29  2006   December   3786593.73
# 25  2006     August   3369796.04
# 27  2006    October   3305908.69
# 2   2004      March   3250045.67
# 12  2005       July   3207633.29
# 4   2004        May   3045549.31
# 15  2005    October   2723960.97
# 14  2005  September   2641326.83
# 23  2006       June   2481533.41
# 26  2006  September   2219281.27
# 17  2005   December   2065042.84

# %%
sns.set_context('notebook')

fig, ax = plt.subplots(figsize=(20,7))

sns.barplot(data=top_months, x='month', y='Amount', hue='year')

plt.title('Top Spending by Month and year.png')
plt.savefig('Q5_Top_Spending_by_Month_and_year.png')
plt.show()

# %% [markdown]
# __6.__ Which month do we record more customers spending money in terms of number of transactions?

# %%
mnth_per_transact = df.groupby('month')['Amount'].count().reset_index()
mnth_per_transact.sort_values(by='Amount', ascending=False, inplace=True)
mnth_per_transact
# Out:
#         month  Amount
# 0     January     349
# 1    February     238
# 2       March     231
# 4         May     210
# 3       April     150
# 10   November      84
# 5        June      56
# 6        July      42
# 7      August      42
# 8   September      42
# 9     October      28
# 11   December      28

# %%
sns.set_context('notebook')

fig, ax = plt.subplots(figsize=(20,7))

sns.barplot(data=mnth_per_transact, x='month', y='Amount',)

plt.title('Top Months by Number of Transaction')
plt.savefig('Q6_Top_Spending_Months_by_transact.png')
plt.show()

# %% [markdown]
# __7.__ What are most customers spending money on, does this change by month?

# %%
spending_type = df.groupby(['month', 'Type', ])['Amount'].sum().reset_index()
spending_type.sort_values(by='Amount', ascending=False, inplace=True)
spending_type.head(10)
# Out:
#        month          Type       Amount
# 4    January        CAMERA  17823032.82
# 7    January          FOOD  11858415.70
# 13   January      SHOPPING   9327906.15
# 10   January         PETRO   9321912.40
# 70       May         PETRO   8452007.03
# 36     March       CLOTHES   7706663.68
# 25  February         PETRO   7665808.46
# 67       May          FOOD   7592141.47
# 29  February  TRAIN TICKET   7214447.96
# 37     March          FOOD   7178372.37

# %%
sns.set_context('notebook')
sns.color_palette('RdPu', 10)

fig, ax = plt.subplots(figsize=(20,7))

sns.barplot(data=spending_type, x='month', y='Amount', hue='Type')

plt.title('Spending pattern by Type')
plt.savefig('Q7_spending_pattern_by_type.png')
plt.show()

# %% [markdown]
# __8.__ What products are users under the age of 21 spending more money on?

# %%
users_u21 = df.loc[df.Age < 21]
users_u21.head()
# Out:
#     Customer  Age     City Product     Limit Company       Segment      Month  \
# 236      A14   16  Nairobi    Gold  500000.0     C14  Salaried_Pvt   1-Apr-06
# 237      A14   16  Nairobi    Gold  500000.0     C14  Salaried_Pvt   1-Feb-05
# 238      A14   16  Nairobi    Gold  500000.0     C14  Salaried_Pvt   1-Feb-05
# 239      A14   16  Nairobi    Gold  500000.0     C14  Salaried_Pvt  11-Jul-06
# 240      A14   16  Nairobi    Gold  500000.0     C14  Salaried_Pvt  15-Jan-04
#
#            Type     Amount       day     month  year
# 236  BUS TICKET  341157.43  Saturday     April  2006
# 237    SHOPPING  463680.60   Tuesday  February  2005
# 238  AIR TICKET  394078.34   Tuesday  February  2005
# 239      CAMERA  268233.08   Tuesday      July  2006
# 240      CAMERA  366089.04  Thursday   January  2004

# %%
users_u21.groupby('Product')['Amount'].sum().reset_index().sort_values(by='Amount', ascending=False)
# Out:
#     Product       Amount
# 1  Platimum  10339766.98
# 0      Gold   8728471.73
# 2    Silver    214636.58

# %%
u21_prouct = users_u21.groupby('Product')['Amount'].sum().reset_index().sort_values(by='Amount', ascending=False)

# %%
sns.set()
sns.set_context('notebook')
fig, ax = plt.subplots()

plt.pie(u21_prouct.Amount, labels=u21_prouct.Product, autopct='%0.2f%%')
plt.title('Under 21 Spending pattern')

plt.savefig('Q8_u21_product_spending.png')
plt.show()

# %% [markdown]
# __9.__ What products are users between the ages of 25 and 40, spending more money on, does this differ depending on the city they are from?

# %%
users_o21 = df.loc[df.Age.between(25, 40)]
users_o21.head()
# Out:
#    Customer  Age    City   Product    Limit Company       Segment      Month  \
# 29       A3   34  Kisumu  Platimum  10000.0      C3  Salaried_Pvt  15-Jan-04
# 30       A3   34  Kisumu  Platimum  10000.0      C3  Salaried_Pvt  16-Feb-05
# 31       A3   34  Kisumu  Platimum  10000.0      C3  Salaried_Pvt  24-May-05
# 32       A3   34  Kisumu  Platimum  10000.0      C3  Salaried_Pvt  25-Mar-06
# 33       A3   34  Kisumu  Platimum  10000.0      C3  Salaried_Pvt  27-Apr-05
#
#             Type     Amount        day     month  year
# 29  MOVIE TICKET  418202.62   Thursday   January  2004
# 30  TRAIN TICKET  194358.94  Wednesday  February  2005
# 31         PETRO  183707.24    Tuesday       May  2005
# 32          FOOD  418516.31   Saturday     March  2006
# 33  TRAIN TICKET   94389.66  Wednesday     April  2005

# %%
o21 = users_o21.groupby(['City', 'Product', ])['Amount'].sum().reset_index().sort_values(by='Amount', ascending=False)

# %%
fig, ax = plt.subplots(figsize=(20, 7))
sns.barplot(data=o21, x='City', y='Amount', hue='Product')
plt.title('Products purchases by city')

plt.savefig('Q9_Spending_Pattern_by_age_and_city')

# %%
for i in o21.City.unique():
    print(o21.loc[o21.City == i])
# Out:
#       City   Product       Amount
# 8  Mombasa  Platimum  25792454.93
# 7  Mombasa      Gold  15597502.98
# 9  Mombasa    Silver   5841663.51
#        City   Product       Amount
# 10  Nairobi      Gold  13354734.98
# 11  Nairobi  Platimum   5683569.97
# 12  Nairobi    Silver   4961749.40
#      City   Product       Amount
# 3  Kisumu    Silver  11163624.78
# 1  Kisumu      Gold   4829942.06
# 2  Kisumu  Platimum   3479189.93
#       City   Product      Amount
# 15  Nakuru    Silver  9059045.42
# 13  Nakuru      Gold  4261646.45
# 14  Nakuru  Platimum   310869.68
#      City   Product     Amount
# 16  Thika  Platimum  7888606.8
#       City Product      Amount
# 6  Malindi    Gold  6876389.81
#      City Product      Amount
# 4  Kitale    Gold  6391189.56
# 5  Kitale  Silver  4032743.60
#       City Product      Amount
# 0  Eldoret    Gold  6189339.25

# %% [markdown]
# ### Additionally

# %%
spending_by_day = df.groupby('day')['Amount'].agg([np.sum, np.mean, ])
spending_by_day
# Out:
#                    sum           mean
# day
# Friday     37947689.48  248024.114248
# Monday     68319298.26  249340.504599
# Saturday   58703377.78  238631.616992
# Sunday     51838730.82  252871.857659
# Thursday   56277490.30  241534.293133
# Tuesday    44370231.88  246501.288222
# Wednesday  47187255.67  225776.342919

# %%
# spending_by_day.sort_values(by='Amount', ascending=False, inplace=True)

# %%
seg_df = df.groupby('Segment')['Amount'].sum().reset_index()
seg_df.sort_values(by='Amount', ascending=False, inplace=True)
seg_df
# Out:
#          Segment        Amount
# 1  Normal Salary  1.076079e+08
# 3   Salaried_Pvt  6.866101e+07
# 4  Self Employed  6.662369e+07
# 0           Govt  6.350277e+07
# 2   Salaried_MNC  5.824866e+07

# %%
sns.set_context('notebook')

plt.pie(seg_df.Amount, labels=seg_df.Segment.unique(), autopct='%0.2f%%')

plt.title('Spending by Segments')

plt.savefig('A1_spending_by_segments.png')
plt.show()

# %%
seg_by_type = df.groupby(['Segment', 'Type'])['Amount'].sum().reset_index()
seg_by_type.sort_values(by='Amount', ascending=False, inplace=True)
seg_by_type.head()
# Out:
#           Segment        Type       Amount
# 25  Normal Salary       PETRO  18247117.44
# 15  Normal Salary  AIR TICKET  12838860.71
# 49   Salaried_Pvt      CAMERA  11425922.89
# 22  Normal Salary        FOOD  10051685.70
# 19  Normal Salary      CAMERA   9776031.25

# %%
sns.set_context('notebook')
fig, ax = plt.subplots(figsize=(20,7))

sns.barplot(data=seg_by_type, x='Type', y='Amount', hue='Segment')

plt.title('Spending Types by Segments')

# plt.savefig('A2_spending_types_by_segment.png')
# Out:
# Text(0.5, 1.0, 'Spending Types by Segments')
